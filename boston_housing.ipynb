# %%
# description
# https://www.kaggle.com/c/boston-housing

# TensorFlow and tf.keras
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.boston_housing.load_data(path='boston_housing.npz')
# Out:
# ...
# 57344/57026 [==============================] - 0s 1us/step

# %% [markdown]
# 데이터의 모양 확인

# %%
x_train.shape
y_train.shape
x_test.shape
y_test
# Out:
# array([ 7.2, 18.8, 19. , 27. , 22.2, 24.5, 31.2, 22.9, 20.5, 23.2, 18.6,
#        14.5, 17.8, 50. , 20.8, 24.3, 24.2, 19.8, 19.1, 22.7, 12. , 10.2,
#        20. , 18.5, 20.9, 23. , 27.5, 30.1,  9.5, 22. , 21.2, 14.1, 33.1,
#        23.4, 20.1,  7.4, 15.4, 23.8, 20.1, 24.5, 33. , 28.4, 14.1, 46.7,
#        32.5, 29.6, 28.4, 19.8, 20.2, 25. , 35.4, 20.3,  9.7, 14.5, 34.9,
#        26.6,  7.2, 50. , 32.4, 21.6, 29.8, 13.1, 27.5, 21.2, 23.1, 21.9,
#        13. , 23.2,  8.1,  5.6, 21.7, 29.6, 19.6,  7. , 26.4, 18.9, 20.9,
#        28.1, 35.4, 10.2, 24.3, 43.1, 17.6, 15.4, 16.2, 27.1, 21.4, 21.5,
#        22.4, 25. , 16.6, 18.6, 22. , 42.8, 35.1, 21.5, 36. , 21.9, 24.1,
#        50. , 26.7, 25. ])

# %% [markdown]
# input과 output의 관계를 plot화 시켜서 확인

# %%
plt.plot(x_train[:,0], y_train, '.')

# %%
model = Sequential()
model.add(Dense(1, input_shape=[13]))
model.compile(optimizer='rmsprop', loss='mse')   #regression의 경우에는 rmsrpor이랑 mse로 적으면 된다
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\pkh02\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\pkh02\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 14
# ...
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#     input 13개
#     output 1개
#     hidden layer 10개 <- relu 식을 사용
#
#     param # : 화살표의 개수인데 14개인 이유는 마지막에 상수 1이 생략되어 있기 때문
#     dense_2는 hidden으로 인해 생긴 것
#     regression(lineary) vs classification(sigmoid/softmax/relu)

# %%
model = Sequential()
model.add(Dense(10, input_shape=[13], activation = 'relu'))   
model.add(Dense(1))   


model.compile(optimizer='rmsprop', loss='mse')  
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 404/404 [==============================] - 0s 387us/sample - loss: 13.7131
# Epoch 2/1000
# 404/404 [==============================] - 0s 348us/sample - loss: 13.4477
# Epoch 3/1000
# 404/404 [==============================] - 0s 232us/sample - loss: 13.3028
# Epoch 4/1000
# 404/404 [==============================] - 0s 271us/sample - loss: 12.4929
# Epoch 5/1000
# 404/404 [==============================] - 0s 232us/sample - loss: 13.8733
# Epoch 6/1000
# 404/404 [==============================] - 0s 232us/sample - loss: 12.9234
# Epoch 7/1000
# 404/404 [==============================] - 0s 193us/sample - loss: 13.3012
# Epoch 8/1000
# 404/404 [==============================] - 0s 232us/sample - loss: 12.7745
# Epoch 9/1000
# 404/404 [==============================] - 0s 193us/sample - loss: 13.0099
# Epoch 10/1000
# 404/404 [==============================] - 0s 271us/sample - loss: 13.3686
# Epoch 11/1000
# ...

# %% [markdown]
# evaluate : process의 경과를 보기 위한 테스트

# %%
model.evaluate(x_test, y_test)
# Out:
# 102/102 [==============================] - 0s 5ms/sample - loss: 32.9765
# 32.976488599590226

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 13)
# (None, 1)

# %%
# INPUT::
# 1. crim: per capita crime rate by town.
# 2. zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. indus: proportion of non-retail business acres per town.
# 4. chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. nox: nitrogen oxides concentration (parts per 10 million).
# 6. rm: average number of rooms per dwelling.
# 7. age: proportion of owner-occupied units built prior to 1940.
# 8. dis: weighted mean of distances to five Boston employment centres.
# 9. rad: index of accessibility to radial highways.
# 10. tax: full-value property-tax rate per $10,000.
# 11. ptratio: pupil-teacher ratio by town.
# 12. black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# 13. lstat: lower status of the population (percent).

# TARGET::
# medv: median value of owner-occupied homes in $1000s.

model.predict(np.array([0, 1, 50, 1, 0, 5, .5, 10, 1000, 100, 10, 100, 1]).reshape(1,13))
# Out:
# array([[638.29156]], dtype=float32)

# %%
boston_housing = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'istat']

for i in range(13):
    plt.subplot(3, 5, i+1)
    plt.plot(x_train[:,i], y_train, '.')
    plt.title(boston_housing[i])
plt.show()

# %% [markdown]
#     normalization : dataset의 평균값을 구한 뒤 모든 data 값에서 평균값(standard deviation)을 빼줌 => -1 ~ 1 을 range로 하는 값
